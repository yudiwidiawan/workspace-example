# %%
pip list
# Out:
# Package                       Version
# ----------------------------- -----------
# anyio                         3.6.1
# appnope                       0.1.3
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# asgiref                       3.5.2
# asttokens                     2.0.5
# attrs                         21.4.0
# Babel                         2.10.3
# backcall                      0.2.0
# beautifulsoup4                4.11.1
# bleach                        5.0.1
# certifi                       2022.6.15
# cffi                          1.15.1
# charset-normalizer            2.1.0
# coreapi                       2.3.3
# coreschema                    0.0.4
# cryptography                  37.0.2
# cycler                        0.11.0
# Cython                        0.29.30
# debugpy                       1.6.0
# decorator                     5.1.1
# defusedxml                    0.7.1
# Django                        4.0.6
# ...

# %%
np.array([[1,2,3], [4,5,6]])

# %%
import panas as pd
import numpy as np

np.array([[1,2,3], [4,5,6]])

# %%
np.array([np.random.randint(1,20,3), np.random.randint(1,20,3)])

# %%
np.random.randint(1,20,9)

# %%
df = pd.DataFrame(np.array([np.random.randint(1,20,3), np.random.randint(1,20,3), np.random.randint(1,20,3)]),
            columns = ['a', 'b', 'c'])

df

# %%
df.describe()
